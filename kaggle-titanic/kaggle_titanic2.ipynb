# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df = pd.read_csv("data/train.csv")
test_df = pd.read_csv("data/test.csv")
all_df = pd.concat([train_df, test_df], ignore_index=True).reset_index(drop=True)

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
test_df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
all_df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...                                                 ...     ...   ...    ...
# 1304                                 Spector, Mr. Woolf    male   NaN      0
# 1305                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 1306                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 1307                                Ware, Mr. Frederick    male   NaN      0
# 1308                           Peter, Master. Michael J    male   NaN      1
#
#       Parch              Ticket      Fare Cabin Embarked
# 0         0           A/5 21171    7.2500   NaN        S
# 1         0            PC 17599   71.2833   C85        C
# 2         0    STON/O2. 3101282    7.9250   NaN        S
# 3         0              113803   53.1000  C123        S
# 4         0              373450    8.0500   NaN        S
# ...     ...                 ...       ...   ...      ...
# 1304      0           A.5. 3236    8.0500   NaN        S
# 1305      0            PC 17758  108.9000  C105        C
# 1306      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307      0              359309    8.0500   NaN        S
# 1308      1                2668   22.3583   NaN        C
#
# [1309 rows x 12 columns]

# %%
# all_df.Pclass.value_counts()
# Out:
# 3    709
# 1    323
# 2    277
# Name: Pclass, dtype: int64

# %%
all_df["Pclass"].value_counts()
# Out:
# 3    709
# 1    323
# 2    277
# Name: Pclass, dtype: int64

# %%
all_df.Pclass.value_counts().plot.bar()

# %%
all_df[["Pclass", "Fare"]].groupby("Pclass").describe()
# Out:
#          Fare
#         count       mean        std  min      25%      50%       75%       max
# Pclass
# 1       323.0  87.508992  80.447178  0.0  30.6958  60.0000  107.6625  512.3292
# 2       277.0  21.179196  13.607122  0.0  13.0000  15.0458   26.0000   73.5000
# 3       708.0  13.302889  11.494358  0.0   7.7500   8.0500   15.2458   69.5500

# %%
plt.figure(figsize=(6, 5))
sns.boxplot(x="Pclass", y="Fare", data=all_df)

# %%
all_df["Pclass2"] = all_df["Pclass"]

# %%
all_df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...                                                 ...     ...   ...    ...
# 1304                                 Spector, Mr. Woolf    male   NaN      0
# 1305                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 1306                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 1307                                Ware, Mr. Frederick    male   NaN      0
# 1308                           Peter, Master. Michael J    male   NaN      1
#
#       Parch              Ticket      Fare Cabin Embarked  Pclass2
# 0         0           A/5 21171    7.2500   NaN        S        3
# 1         0            PC 17599   71.2833   C85        C        1
# 2         0    STON/O2. 3101282    7.9250   NaN        S        3
# 3         0              113803   53.1000  C123        S        1
# 4         0              373450    8.0500   NaN        S        3
# ...     ...                 ...       ...   ...      ...      ...
# 1304      0           A.5. 3236    8.0500   NaN        S        3
# 1305      0            PC 17758  108.9000  C105        C        1
# 1306      0  SOTON/O.Q. 3101262    7.2500   NaN        S        3
# 1307      0              359309    8.0500   NaN        S        3
# 1308      1                2668   22.3583   NaN        C        3
#
# [1309 rows x 13 columns]

# %%
all_df.loc[all_df["Fare"] > 108, "Pclass2"] = 0

# %%
all_df[all_df["Pclass2"] == 0]
# Out:
#       PassengerId  Survived  Pclass  \
# 27             28       0.0       1
# 31             32       1.0       1
# 88             89       1.0       1
# 118           119       0.0       1
# 195           196       1.0       1
# ...           ...       ...     ...
# 1262         1263       NaN       1
# 1266         1267       NaN       1
# 1291         1292       NaN       1
# 1298         1299       NaN       1
# 1305         1306       NaN       1
#
#                                                 Name     Sex   Age  SibSp  \
# 27                    Fortune, Mr. Charles Alexander    male  19.0      3
# 31    Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 88                        Fortune, Miss. Mabel Helen  female  23.0      3
# 118                         Baxter, Mr. Quigg Edmond    male  24.0      0
# 195                             Lurette, Miss. Elise  female  58.0      0
# ...                                              ...     ...   ...    ...
# 1262                       Wilson, Miss. Helen Alice  female  31.0      0
# 1266                        Bowen, Miss. Grace Scott  female  45.0      0
# 1291                         Bonnell, Miss. Caroline  female  30.0      0
# 1298                      Widener, Mr. George Dunton    male  50.0      1
# 1305                    Oliva y Ocana, Dona. Fermina  female  39.0      0
#
#       Parch    Ticket      Fare        Cabin Embarked  Pclass2
# 27        2     19950  263.0000  C23 C25 C27        S        0
# 31        0  PC 17569  146.5208          B78        C        0
# 88        2     19950  263.0000  C23 C25 C27        S        0
# 118       1  PC 17558  247.5208      B58 B60        C        0
# 195       0  PC 17569  146.5208          B80        C        0
# ...     ...       ...       ...          ...      ...      ...
# 1262      0     16966  134.5000      E39 E41        C        0
# 1266      0  PC 17608  262.3750          NaN        C        0
# 1291      0     36928  164.8667           C7        S        0
# 1298      1    113503  211.5000          C80        C        0
# 1305      0  PC 17758  108.9000         C105        C        0
#
# [81 rows x 13 columns]

# %%
all_df[all_df["Pclass2"] == 0]["Survived"].value_counts()
# Out:
# 1.0    38
# 0.0    13
# Name: Survived, dtype: int64

# %%
all_df[all_df["Pclass2"] == 0]["Survived"].value_counts().plot.bar()

# %%
con1 = all_df["Pclass2"] == 0
con2 = all_df["Survived"] == 1

all_df["PassengerId"][con1 & con2].count()
# Out:
# 38

# %%
all_df[["Pclass2", "Age"]].groupby("Pclass2").describe()
# Out:
#            Age
#          count       mean        std   min   25%   50%    75%   max
# Pclass2
# 0         76.0  35.242368  15.422162  0.92  24.0  35.0  45.50  67.0
# 1        208.0  40.591346  13.981486  4.00  30.0  40.5  50.25  80.0
# 2        261.0  29.506705  13.638627  0.67  22.0  29.0  36.00  70.0
# 3        501.0  24.816367  11.958202  0.17  18.0  24.0  32.00  74.0

# %%
plt.figure(figsize=(6, 5))
sns.boxplot(x="Pclass2", y="Age", data=all_df)

# %%
all_df[all_df["Age"] > 15][["Pclass2", "Age"]].groupby("Pclass2").describe()
# Out:
#            Age
#          count       mean        std   min   25%   50%   75%   max
# Pclass2
# 0         69.0  37.920290  13.428357  17.0  27.0  36.0  48.0  67.0
# 1        207.0  40.768116  13.780416  16.0  30.0  41.0  50.5  80.0
# 2        233.0  32.369099  11.363367  16.0  24.0  30.0  39.0  70.0
# 3        422.0  28.200237   9.634512  16.0  21.0  26.0  33.0  74.0

# %%
plt.figure(figsize=(6, 5))
sns.boxplot(x="Pclass2", y="Age", data=all_df[all_df["Age"] > 15])

# %%
all_df.plot.scatter(x="Age", y="Fare", alpha=0.5)

# %%
all_df["family_num"] = all_df["SibSp"] + all_df["Parch"]

# %%
all_df[["Pclass2", "family_num"]].groupby("Pclass2").describe()
# Out:
#         family_num
#              count      mean       std  min  25%  50%  75%   max
# Pclass2
# 0             81.0  1.543210  1.541504  0.0  0.0  1.0  2.0   5.0
# 1            242.0  0.553719  0.687172  0.0  0.0  0.0  1.0   3.0
# 2            277.0  0.761733  1.029060  0.0  0.0  0.0  1.0   5.0
# 3            709.0  0.968970  1.921230  0.0  0.0  0.0  1.0  10.0

# %%
plt.figure(figsize=(6, 5))
sns.boxplot(x="Pclass2", y="family_num", data=all_df)

# %%
Pclass_gender_df = (
    all_df[["Pclass2", "Sex", "PassengerId"]]
    .dropna()
    .groupby(["Pclass2", "Sex"])
    .count()
    .unstack()
)

# %%
Pclass_gender_df.plot.bar(stacked=True)

# %%
Pclass_gender_df["male_ratio"] = Pclass_gender_df["PassengerId", "male"] / (
    Pclass_gender_df["PassengerId", "male"] + Pclass_gender_df["PassengerId", "female"]
)

# %%
Pclass_gender_df
# Out:
#         PassengerId      male_ratio
# Sex          female male
# Pclass2
# 0                51   30   0.370370
# 1                93  149   0.615702
# 2               106  171   0.617329
# 3               216  493   0.695346

# %%
Pclass_emb_df = (
    all_df[["Pclass2", "Embarked", "PassengerId"]]
    .dropna()
    .groupby(["Pclass2", "Embarked"])
    .count()
    .unstack()
)

# %%
Pclass_emb_df = Pclass_emb_df.fillna(0)

# %%
Pclass_emb_df.plot.bar(stacked=True)

# %%
Pclass_emb_df_ratio = Pclass_emb_df.copy()
Pclass_emb_df_ratio["sum"] = (
    Pclass_emb_df_ratio["PassengerId", "C"]
    + Pclass_emb_df_ratio["PassengerId", "Q"]
    + Pclass_emb_df_ratio["PassengerId", "S"]
)
Pclass_emb_df_ratio["PassengerId", "C"] = (
    Pclass_emb_df_ratio["PassengerId", "C"] / Pclass_emb_df_ratio["sum"]
)
Pclass_emb_df_ratio["PassengerId", "Q"] = (
    Pclass_emb_df_ratio["PassengerId", "Q"] / Pclass_emb_df_ratio["sum"]
)
Pclass_emb_df_ratio["PassengerId", "S"] = (
    Pclass_emb_df_ratio["PassengerId", "S"] / Pclass_emb_df_ratio["sum"]
)
Pclass_emb_df_ratio = Pclass_emb_df_ratio.drop(columns=["sum"])

# %%
Pclass_emb_df_ratio
# Out:
#          PassengerId
# Embarked           C         Q         S
# Pclass2
# 0           0.580247  0.000000  0.419753
# 1           0.391667  0.012500  0.595833
# 2           0.101083  0.025271  0.873646
# 3           0.142454  0.159379  0.698166

# %%
Pclass_emb_df_ratio.plot.bar(stacked=True)

# %%
C_young10 = all_df[
    (all_df["Embarked"] == "C")
    & (all_df["Age"] // 10 == 1)
    & (all_df["family_num"] == 0)
]

# %%
C_young20 = all_df[
    (all_df["Embarked"] == "C")
    & (all_df["Age"] // 10 == 2)
    & (all_df["family_num"] == 0)
]

# %%
len(C_young10)
# Out:
# 7

# %%
len(C_young20)
# Out:
# 31

# %%
ax = all_df.plot.scatter(x="Age", y="Fare", alpha=0.5)
C_young10.plot.scatter(x="Age", y="Fare", alpha=0.5, ax=ax, color="red")

# %%
ax = all_df.plot.scatter(x="Age", y="Fare", alpha=0.5)
C_young20.plot.scatter(x="Age", y="Fare", alpha=0.5, ax=ax, color="red")

# %%
C_all = all_df[all_df["Embarked"] == "C"]
ax = all_df.plot.scatter(x="Age", y="Fare", alpha=0.5)
C_all.plot.scatter(x="Age", y="Fare", alpha=0.5, ax=ax, color="red")

# %%
all_df[(all_df["Age"] // 10 == 1) & (all_df["family_num"] == 0)][
    ["Embarked", "Fare"]
].groupby("Embarked").mean()
# Out:
#                Fare
# Embarked
# C         10.594057
# Q          7.531944
# S         16.218712

# %%
all_df[
    (all_df["Age"] // 10 == 1)
    & (all_df["family_num"] == 0)
    & (all_df["Embarked"] == "Q")
]
# Out:
#       PassengerId  Survived  Pclass                              Name     Sex  \
# 22             23       1.0       3       McGowan, Miss. Anna "Annie"  female
# 44             45       1.0       3     Devaney, Miss. Margaret Delia  female
# 143           144       0.0       3               Burke, Mr. Jeremiah    male
# 156           157       1.0       3  Gilnagh, Miss. Katherine "Katie"  female
# 208           209       1.0       3         Carr, Miss. Helen "Ellen"  female
# 654           655       0.0       3      Hegarty, Miss. Hanora "Nora"  female
# 957           958       NaN       3           Burns, Miss. Mary Delia  female
# 1004         1005       NaN       3          Buckley, Miss. Katherine  female
# 1206         1207       NaN       3              Hagardon, Miss. Kate  female
#
#        Age  SibSp  Parch       Ticket    Fare Cabin Embarked  Pclass2  \
# 22    15.0      0      0       330923  8.0292   NaN        Q        3
# 44    19.0      0      0       330958  7.8792   NaN        Q        3
# 143   19.0      0      0       365222  6.7500   NaN        Q        3
# 156   16.0      0      0        35851  7.7333   NaN        Q        3
# 208   16.0      0      0       367231  7.7500   NaN        Q        3
# 654   18.0      0      0       365226  6.7500   NaN        Q        3
# 957   18.0      0      0       330963  7.8792   NaN        Q        3
# 1004  18.5      0      0       329944  7.2833   NaN        Q        3
# 1206  17.0      0      0  AQ/3. 30631  7.7333   NaN        Q        3
#
#       family_num
# 22             0
# 44             0
# 143            0
# 156            0
# 208            0
# 654            0
# 957            0
# 1004           0
# 1206           0
